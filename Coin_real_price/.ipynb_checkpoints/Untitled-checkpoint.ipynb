# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome(executable_path="D:\\USERS\\szhu76\\Downloads\\chromedriver_win32\\chromedriver")
# Out:
# C:\Users\szhu76\AppData\Local\Temp\40\ipykernel_371652\2813530763.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="D:\\USERS\\szhu76\\Downloads\\chromedriver_win32\\chromedriver")
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# d:\Shuai-Jingbo-Pei-yu\CoinMarketCap_CoinPrice_data\Coin_real_price\.ipynb_checkpoints\Untitled-checkpoint.ipynb Cell 2' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Shuai-Jingbo-Pei-yu/CoinMarketCap_CoinPrice_data/Coin_real_price/.ipynb_checkpoints/Untitled-checkpoint.ipynb#ch0000001?line=0'>1</a> driver = webdriver.Chrome(executable_path="D:\\USERS\\szhu76\\Downloads\\chromedriver_win32\\chromedriver")
#
# ...
